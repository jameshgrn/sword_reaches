# %%
import ee
import geemap

ee.Initialize()

def mask_s2_clouds(image):
  """Masks clouds in a Sentinel-2 image using the QA band.

  Args:
      image (ee.Image): A Sentinel-2 image.

  Returns:
      ee.Image: A cloud-masked Sentinel-2 image.
  """
  qa = image.select('QA60')

  # Bits 10 and 11 are clouds and cirrus, respectively.
  cloud_bit_mask = 1 << 10
  cirrus_bit_mask = 1 << 11

  # Both flags should be set to zero, indicating clear conditions.
  mask = (
      qa.bitwiseAnd(cloud_bit_mask)
      .eq(0)
      .And(qa.bitwiseAnd(cirrus_bit_mask).eq(0))
  )

  return image.updateMask(mask).divide(10000)


dataset = (
    ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
    .filterDate('2016-01-01', '2016-12-28')
    # Pre-filter to get less cloudy granules.
    .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30))
    .map(mask_s2_clouds)
)

visualization = {
    'min': 0.0,
    'max': 0.3,
    'bands': ['B4', 'B3', 'B2'],
}

m = geemap.Map()
m.add_layer(dataset.mean(), visualization, 'RGB')
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=SearchDataGUI(childr…

# %%
# Construct a collection of corresponding Dynamic World and Sentinel-2 for
# inspection. Filter the DW and S2 collections by region and date.
START = ee.Date('2016-04-02')
END = START.advance(1, 'day')

col_filter = ee.Filter.And(
    ee.Filter.bounds(ee.Geometry.Point(20.6729, 52.4305)),
    ee.Filter.date(START, END),
)

dw_col = ee.ImageCollection('GOOGLE/DYNAMICWORLD/V1').filter(col_filter)
s2_col = ee.ImageCollection('COPERNICUS/S2').filter(col_filter)

# Join corresponding DW and S2 images (by system:index).
dw_s2_col = ee.Join.saveFirst('s2_img').apply(
    dw_col,
    s2_col,
    ee.Filter.equals(leftField='system:index', rightField='system:index'),
)

# Extract an example DW image and its source S2 image.
dw_image = ee.Image(dw_s2_col.first())
s2_image = ee.Image(dw_image.get('s2_img'))

# Create a visualization that blends DW class label with probability.
# Define list pairs of DW LULC label and color.
CLASS_NAMES = [
    'water',
    'trees',
    'grass',
    'flooded_vegetation',
    'crops',
    'shrub_and_scrub',
    'built',
    'bare',
    'snow_and_ice',
]

VIS_PALETTE = [
    '419bdf',
    '397d49',
    '88b053',
    '7a87c6',
    'e49635',
    'dfc35a',
    'c4281b',
    'a59b8f',
    'b39fe1',
]

# Create an RGB image of the label (most likely class) on [0, 1].
dw_rgb = (
    dw_image.select('label')
    .visualize(min=0, max=8, palette=VIS_PALETTE)
    .divide(255)
)

# Get the most likely class probability.
top1_prob = dw_image.select(CLASS_NAMES).reduce(ee.Reducer.max())

# Create a hillshade of the most likely class probability on [0, 1]
top1_prob_hillshade = ee.Terrain.hillshade(top1_prob.multiply(100)).divide(255)

# Combine the RGB image with the hillshade.
dw_rgb_hillshade = dw_rgb.multiply(top1_prob_hillshade)

# Display the Dynamic World visualization with the source Sentinel-2 image.
m = geemap.Map()
m.set_center(20.6729, 52.4305, 12)
m.add_layer(
    s2_image,
    {'min': 0, 'max': 3000, 'bands': ['B4', 'B3', 'B2']},
    'Sentinel-2 L1C',
)
m.add_layer(
    dw_rgb_hillshade,
    {'min': 0, 'max': 0.65},
    'Dynamic World V1 - label hillshade',
)
m
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/ee/data.py:383, in _execute_cloud_call(call, num_retries)
#     382 try:
# --> 383   return call.execute(num_retries=num_retries)
#     384 except googleapiclient.errors.HttpError as e:
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps?fields=name&alt=json returned "Element.get: Parameter 'object' is required.". Details: "Element.get: Parameter 'object' is required.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Cell In[7], line 70
#      68 m = geemap.Map()
#      69 m.set_center(20.6729, 52.4305, 12)
# ---> 70 m.add_layer(
#      71     s2_image,
#      72     {'min': 0, 'max': 3000, 'bands': ['B4', 'B3', 'B2']},
#      73     'Sentinel-2 L1C',
#      74 )
#      75 m.add_layer(
#      76     dw_rgb_hillshade,
#      77     {'min': 0, 'max': 0.65},
#      78     'Dynamic World V1 - label hillshade',
#      79 )
#      80 m
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/geemap/core.py:754, in Map.add_layer(self, ee_object, vis_params, name, shown, opacity)
#     752 if name is None:
#     753     name = f"Layer {len(self.ee_layers) + 1}"
# --> 754 tile_layer = ee_tile_layers.EELeafletTileLayer(
#     755     ee_object, vis_params, name, shown, opacity
#     756 )
#     758 # Remove the layer if it already exists.
#     759 self.remove(name)
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/geemap/ee_tile_layers.py:144, in EELeafletTileLayer.__init__(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     134 """Initialize the ipyleaflet tile layer.
#     135
#     136 Args:
#    (...)
#     141     opacity (float, optional): The layer's opacity represented as a number between 0 and 1. Defaults to 1.
#     142 """
#     143 self._ee_object = ee_object
# --> 144 self.url_format = _get_tile_url_format(
#     145     ee_object, _validate_vis_params(vis_params)
#     146 )
#     147 super().__init__(
#     148     url=self.url_format,
#     149     attribution="Google Earth Engine",
#    (...)
#     154     **kwargs,
#     155 )
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/geemap/ee_tile_layers.py:19, in _get_tile_url_format(ee_object, vis_params)
#      17 def _get_tile_url_format(ee_object, vis_params):
#      18     image = _ee_object_to_image(ee_object, vis_params)
# ---> 19     map_id_dict = ee.Image(image).getMapId(vis_params)
#      20     return map_id_dict["tile_fetcher"].url_format
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/ee/image.py:130, in Image.getMapId(self, vis_params)
#     128 vis_image, request = self._apply_visualization(vis_params)
#     129 request['image'] = vis_image
# --> 130 response = data.getMapId(request)
#     131 response['image'] = self
#     132 return response
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/ee/data.py:705, in getMapId(params)
#     700 queryParams = {
#     701     'fields': 'name',
#     702     'body': request,
#     703 }
#     704 _maybe_populate_workload_tag(queryParams)
# --> 705 result = _execute_cloud_call(
#     706     _get_cloud_projects()
#     707     .maps()
#     708     .create(parent=_get_projects_path(), **queryParams)
#     709 )
#     710 map_name = result['name']
#     711 url_format = '%s/%s/%s/tiles/{z}/{x}/{y}' % (
#     712     _tile_base_url, _cloud_api_utils.VERSION, map_name)
#
# File ~/CursorProjects/sword_reaches/.venv/lib/python3.9/site-packages/ee/data.py:385, in _execute_cloud_call(call, num_retries)
#     383   return call.execute(num_retries=num_retries)
#     384 except googleapiclient.errors.HttpError as e:
# --> 385   raise _translate_cloud_exception(e)
#
# EEException: Element.get: Parameter 'object' is required.

# %%
# Assuming the rest of the code is unchanged and focusing on the new algorithm.

# Define the stable classes and classes of interest for change detection.
STABLE_CLASSES = ['grass', 'flooded_vegetation']
CHANGE_CLASSES = ['water', 'bare']

# Function to detect changes from stable classes to change classes.
def detect_changes(image):
    # Create a mask for stable classes.
    stable_mask = image.select(STABLE_CLASSES).reduce(ee.Reducer.sum()).gt(0)
    
    # Create a mask for change classes.
    change_mask = image.select(CHANGE_CLASSES).reduce(ee.Reducer.sum()).gt(0)
    
    # Detect changes by finding where stable classes are replaced by change classes.
    changes = stable_mask.And(change_mask.Not())
    
    return image.updateMask(changes)

# Apply the change detection algorithm over the collection.
change_collection = dw_col.map(detect_changes)

# Filter for short-term changes, assuming 'short-term' is defined as less than a month.
# This is a placeholder for the actual logic you would need to implement based on your definition of 'short-term'.
short_term_changes = change_collection.filter(...) # Implement the actual short-term change detection logic here.

# Visualize the results.
m = geemap.Map()
# Add layers to the map for visualization.
# You would need to define the visualization parameters based on your needs.
m.addLayer(short_term_changes, {}, 'Short-term Changes')
m.centerObject(ee.Geometry.Point(20.6729, 52.4305), 12)
m
